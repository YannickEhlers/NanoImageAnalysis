# %%
#Import Data
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, segmentation, feature, future, color, io
from sklearn.ensemble import RandomForestClassifier
from functools import partial
import imageio.v2 as imageio

img = io.imread('Bild1.png',as_gray = True)
io.imshow(img)

# %%
# Build an array of labels for training the segmentation.
training_labels = np.zeros(im.shape[:2], dtype=np.uint8)
training_labels[117:150, 132:142] = 1
training_labels[455:492, 169:184] = 1
training_labels[281:286, 572:576] = 1
training_labels[207:209, 173:175] = 1
training_labels[285:298, 64:70] = 1
training_labels[485:487, 281:221] = 1

training_labels[421:544, 503:615] = 2
training_labels[51:126, 212:259] = 2
training_labels[436:592, 49:100] = 2

training_labels = np.rot90(np.fliplr(training_labels))

io.imshow(training_labels)

# %%
sigma_min = 1
sigma_max = 16
features_func = partial(feature.multiscale_basic_features,
                        intensity=True, edges=False, texture=True,
                        sigma_min=sigma_min, sigma_max=sigma_max,
                        channel_axis=-1)
features = features_func(img)
#clf = RandomForestClassifier(n_estimators=50, n_jobs=-1,
#                             max_depth=10, max_samples=0.05)
#clf = future.fit_segmenter(training_labels, features, clf)
#result = future.predict_segmenter(features, clf)

#fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(9, 4))
#ax[0].imshow(segmentation.mark_boundaries(img, result, mode='thick'))
#ax[0].contour(training_labels)
#ax[0].set_title('Image, mask and segmentation boundaries')
#ax[1].imshow(result)
#ax[1].set_title('Segmentation')
#fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[76], line 7
#       2 sigma_max = 16
#       3 features_func = partial(feature.multiscale_basic_features,
#       4                         intensity=True, edges=False, texture=True,
#       5                         sigma_min=sigma_min, sigma_max=sigma_max,
#       6                         channel_axis=-1)
# ----> 7 features = features_func(img)
#       8 #clf = RandomForestClassifier(n_estimators=50, n_jobs=-1,
#       9 #                             max_depth=10, max_samples=0.05)
#      10 #clf = future.fit_segmenter(training_labels, features, clf)
#    (...)
#      18 #ax[1].set_title('Segmentation')
#      19 #fig.tight_layout()
#
# File /lib/python3.10/site-packages/skimage/_shared/utils.py:348, in deprecate_multichannel_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
# ...
